# %% [markdown]
# Plot some example networks

# %%
from opynions.core.utils import get_graphs, get_opinion_hist
from opynions.analysis.utils import plot_graph

g, _ = get_graphs(1, 1000, 10000, 0.1, 0.2, 20)
get_opinion_hist
plot_graph(g[0])

# %% [markdown]
# Generate a series of heatmaps for each metric

# %% [markdown]
# Generate a series of slices for each metric.

# %%
from opynions.demo import slice_plots

epsilon_values = np.linspace(0,0.5,51)
mu_value = 0.1

slice_plots(epsilon_values, mu_value, 20, 100, 10, 2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from opynions.demo import slice_plots
#       3 epsilon_values = np.linspace(0,0.5,51)
#       4 mu_value = 0.1
#
# File ~/CLS/CSS/CSS_SocialPolarization/opynions/demo.py:5
#       3 import os
#       4 import numpy as np
# ----> 5 from analysis.multiprocessing import multiprocess_all
#       6 from analysis.utils import list_of_dicts_to_csv, plot_subplots_from_csv
#       8 def slice_plots(epsilon, mu,
#       9                 n_runs, n_nodes, time_steps, m_ba, keep_csv=False):
#
# ModuleNotFoundError: No module named 'analysis'

# %% [markdown]
# Finite size scaling analysis for variance (at $\mu = 48$)
